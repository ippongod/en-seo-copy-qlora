# %% [markdown]
# # English SEO Copy Generator — QLoRA ($0)
#
# One-click pipeline: **clone → install → assert masking → train → eval → fill results → download adapter**.
#
# 1. `Runtime → Change runtime type → T4 GPU`
# 2. `Runtime → Run all`
#
# Training is QLoRA (4-bit NF4) with completion-only loss. No paid APIs, no keys.

# %% [markdown]
# ## 1. Clone the repository

# %%
![ -d en-seo-copy-qlora ] || git clone https://github.com/ippongod/en-seo-copy-qlora.git
# %cd en-seo-copy-qlora

# %% [markdown]
# ## 2. Install pinned dependencies

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 3. Prove the completion-only masking (asserts before any GPU time)

# %%
# !nvidia-smi -L
# !python scripts/check_masking.py

# %% [markdown]
# ## 4. Train (QLoRA, completion-only)

# %%
# !python scripts/train.py

# %% [markdown]
# ## 5. Evaluate (base vs. fine-tuned, held-out 10%)

# %%
# !python scripts/eval.py

# %% [markdown]
# ## 6. Fill the README results block and show the report

# %%
# !python scripts/fill_results.py
print(open('results.md', encoding='utf-8').read())

# %% [markdown]
# ## 7. Download the trained adapter

# %%
# !zip -r -q seo-qlora-adapter.zip seo-qlora-adapter
from google.colab import files
files.download('seo-qlora-adapter.zip')
